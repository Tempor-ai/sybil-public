# %% [markdown]
# Check Python version

# %%
# !python --version
# Out:
# Python 3.11.11

# %% [markdown]
# Import libraries

# %%
import json
import yaml
import requests
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %% [markdown]
# ### **Extract Data**

# %%
# Local directory
# data_dir = '../datasets/air_quality'
# file_name = 'air_quality'
file_path = 'air_quality.csv'

# %%
dataset = pd.read_csv(file_path)
dataset=dataset.head(500)

# %%
dataset.shape
# Out:
# (500, 14)

# %%
dataset.columns
# Out:
# Index(['datetime', 'CO(GT)', 'PT08.S1(CO)', 'NMHC(GT)', 'C6H6(GT)',
#        'PT08.S2(NMHC)', 'NOx(GT)', 'PT08.S3(NOx)', 'NO2(GT)', 'PT08.S4(NO2)',
#        'PT08.S5(O3)', 'RH', 'AH', 'T'],
#       dtype='object')

# %%
dataset.head()
# Out:
#            datetime  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  PT08.S2(NMHC)  \
# 0  10-03-2004 18:00     2.6         1360       150      11.9           1046
# 1  10-03-2004 19:00     2.0         1292       112       9.4            955
# 2  10-03-2004 20:00     2.2         1402        88       9.0            939
# 3  10-03-2004 21:00     2.2         1376        80       9.2            948
# 4  10-03-2004 22:00     1.6         1272        51       6.5            836
#
#    NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)    RH      AH  \
# 0      166          1056      113          1692         1268  48.9  0.7578
# 1      103          1174       92          1559          972  47.7  0.7255
# 2      131          1140      114          1555         1074  54.0  0.7502
# 3      172          1092      122          1584         1203  60.0  0.7867
# 4      131          1205      116          1490         1110  59.6  0.7888
#
#       T
# 0  13.6
# 1  13.3
# 2  11.9
# 3  11.0
# 4  11.2

# %%
dataset.tail()
# Out:
#              datetime  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  PT08.S2(NMHC)  \
# 495  31-03-2004 09:00     2.2         1262       216       8.6            924
# 496  31-03-2004 10:00     1.7         1197       117       6.5            837
# 497  31-03-2004 11:00     1.9         1277       156       7.7            886
# 498  31-03-2004 12:00     2.9         1430       332      11.3           1025
# 499  31-03-2004 13:00     2.2         1242       232       9.1            944
#
#      NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)    RH      AH  \
# 495      181           872      125          1576         1093  74.4  0.9384
# 496      144           957      118          1498          965  71.0  0.9582
# 497      140           902      109          1579         1004  70.0  0.9924
# 498      204           779      123          1772         1166  73.3  1.0442
# 499      149           846      114          1638          991  78.1  1.0411
#
#         T
# 495  10.4
# 496  11.5
# 497  12.2
# 498  12.3
# 499  11.3

# %% [markdown]
# Define the required time and target columns

# %%
time_col = dataset.columns[0]
dataset[time_col] = pd.to_datetime(dataset[time_col], format="%d-%m-%Y %H:%M", errors='coerce')
time_col = dataset.columns[0]
target_col = dataset.columns[-1]
dataset[time_col] = dataset[time_col].astype(str)

# %% [markdown]
# Change target column to float

# %%
# dataset[target_col] = dataset[target_col].astype(float)

# %%
# dataset.head()

# %% [markdown]
# Split dataset into train and test sets

# %%
train_size = 0.9
train_points = int(train_size*len(dataset))
train_df = dataset.iloc[:train_points]
test_df = dataset.iloc[train_points:]

# %% [markdown]
# Plot graph

# %%
figsize = (16, 8)
train_df.set_index(time_col)[target_col].plot(figsize=figsize);

# %% [markdown]
# ### **Train API**

# %% [markdown]
# Train data: convert df to list-of-list

# %%
train_data = []
for value in train_df.values:
    train_data.append(list(value))

# %%
train_data[:2]
# Out:
# [['2004-03-10 18:00:00',
#   2.6,
#   1360,
#   150,
#   11.9,
#   1046,
#   166,
#   1056,
#   113,
#   1692,
#   1268,
#   48.9,
#   0.7578,
#   13.6],
#  ['2004-03-10 19:00:00',
#   2.0,
#   1292,
#   112,
#   9.4,
#   955,
#   103,
#   1174,
#   92,
#   1559,
#   972,
#   47.7,
#   0.7255,
#   13.3]]

# %% [markdown]
# Custom Model Request (optional)

# %%
# Default model request
# model_request = {
#     'type': 'meta_lr',
#     'scorers': ['smape', 'mase'],
#     'params': {
#         'preprocessors': [
#             {'type': 'dartsimputer'},
#             {'type': 'minmaxscaler'},
#         ],
#         'base_models': [
#             {'type': 'darts_naive'},
#             {'type': 'darts_seasonalnaive'},
#             {'type': 'darts_autotheta'},
#             {'type': 'darts_autoarima'},
#             {'type': 'darts_autoets'},
#         ],
#     },
# }

# Onboard NeuralProphet customized model request
np_external_model_request = {
    'params': {
      'changepoints_range': 0.2,
      'epochs': 2,
      'growth': 'off'
    },
    'metrics': [],
    'type': 'neuralprophet',
}
# np_external_model_request = None

# Deep SYBIL customized model request
ds_external_model_request = {
    'type': 'meta_wa',  # 'meta_naive', 'meta_wa'
    'scorers': ['mase', 'smape'],
    'params': {
        'preprocessors': [
            # {'type': 'dartsimputer'},
            # {'type': 'simpleimputer', 'params': {'strategy': 'mean'}},
            {'type': 'minmaxscaler'},
        ],
        'base_models': [
            # {'type': 'darts_rnn',
            #  'params': {
            #      'model': 'LSTM',
            #      'hidden_dim': 10,
            #      'n_rnn_layers': 3
            # }},
            # {'type': 'darts_blockrnn'},
            # {'type': 'darts_nlinear'},
            # {'type': 'darts_dlinear'},
            # {'type': 'darts_tsmixer',
            #  'params': {
            #      'output_chunk_length': 24,
            #      'input_chunk_length': 48,                 
            #      'n_epochs': 20,
            # }},
            {'type': 'darts_tsmixer',       
                'params': {    
                 'n_epochs': 20,
            }                
                },
            # {'type': 'darts_tide'},
        ],
    },
}
# ds_external_model_request = None

# Customized model request
model_request = {
    'type': 'meta_wa',  # 'meta_naive', 'meta_wa'
    'scorers': ['mase', 'smape'],
    'params': {
        'preprocessors': [
            # {'type': 'dartsimputer'},
            # {'type': 'simpleimputer', 'params': {'strategy': 'mean'}},
            # {'type': 'minmaxscaler'},
        ],
        'base_models': [
            # {'type': 'darts_naive'},
            # {'type': 'darts_seasonalnaive'},
            # {'type': 'darts_autotheta'},
            # {'type': 'stats_autotheta'},
            # {'type': 'darts_autoets'},
            # {'type': 'stats_autoets'},
            # {'type': 'darts_autoarima'},
            # {'type': 'stats_autoarima'},
            # {'type': 'darts_autoces'},
            # {'type': 'darts_kalman'},
            # {'type': 'darts_catboost'},            
            # {'type': 'darts_tbats'},
            # {'type': 'darts_linearregression'},
            # {'type': 'darts_lightgbm',
            #  'params': {
            #      'lags': 12,
            #      'output_chunk_length': 6,
            #      'verbose': -1
            # }}
            # {'type': 'neuralprophet',
            #  'external_params': np_external_model_request
            # },  # Onboard NeuralProphet external service
            {'type': 'deepsybil',
             'external_params': ds_external_model_request
            }  # Deep SYBIL external service
        ],
    },
}

# %% [markdown]
# This is for JSON model_request

# %%
# file_path = 'model_request.json'
# # For writing the model request to a json file
# with open(file_path, 'r') as file:
#     model_request = json.load(file)

# %% [markdown]
# This is for YAML model_request

# %%
# file_path = 'model_request.yaml'
# # For reading the model request from a yaml file
# with open(file_path, 'r') as file:
#     model_request = yaml.safe_load(file)

# %% [markdown]
# Train API JSON Payload

# %%
api_json = {
    'data': train_data,
    'model': model_request  # (optional) can be commented out
}

# %% [markdown]
# Build URL

# %%
with open('url.yaml', 'r') as file:
    url_dict = yaml.safe_load(file)

# %%
# URL to our SYBIL AWS service
protocol = url_dict['protocol']
host = url_dict['host']
port = url_dict['port']
endpoint = 'train'

url = '%s://%s:%s/%s' % (protocol, host, str(port), endpoint)

# %%
# protocol, host, port

# %% [markdown]
# Call endpoint, receive response JSON, write to output file

# %%
# %%time
response = requests.post(url, json=api_json)
print(response)
print()
# Out:
# <Response [200]>
#
# CPU times: total: 15.6 ms
# Wall time: 1min 37s

# %%
train_json_out = response.json()  # dict output
train_json_out
# Out:
# {'model': '...',
#  'type': 'meta_wa',
#  'metrics': [{'type': 'mase', 'value': 1.3152388662338856},
#   {'type': 'smape', 'value': 10.349379536809021}],
#  'estimate': None}

# %% [markdown]
# ### **Forecast API**

# %% [markdown]
# Forecast Dates: predict the next 32 years of temperature anomaly data (1980-2012)

# %%
test_data = []
for value in test_df.drop(columns=target_col).values:
    test_data.append(list(value))

# %%
test_data[:2]
# Out:
# [['2004-03-29 12:00:00',
#   1.4,
#   971,
#   91,
#   5.5,
#   786,
#   92,
#   1129,
#   78,
#   1272,
#   546,
#   29.0,
#   0.5406],
#  ['2004-03-29 13:00:00',
#   1.6,
#   1010,
#   146,
#   6.5,
#   833,
#   91,
#   1070,
#   83,
#   1332,
#   561,
#   27.9,
#   0.5517]]

# %% [markdown]
# Model from Train API

# %%
model = train_json_out['model']

# %% [markdown]
# Forecast API JSON Payload

# %%
api_json = {
    'model': model,
    'data': test_data
}

# %% [markdown]
# Build URL (same as train except for the endpoint)

# %%
endpoint = 'forecast'

url = '%s://%s:%s/%s' % (protocol, host, str(port), endpoint)

# %% [markdown]
# Call endpoint, receive response JSON, write to output file

# %%
# %%time
response = requests.post(url, json=api_json)
print(response)
print()
# Out:
# <Response [200]>
#
# CPU times: total: 0 ns
# Wall time: 646 ms

# %%
forecast_json_out = response.json()  # dict output
forecast_json_out
# Out:
# {'data': [['2004-03-29 12:00:00', 17.405947766139114],
#   ['2004-03-29 13:00:00', 18.53234494472812],
#   ['2004-03-29 14:00:00', 18.98179933924647],
#   ['2004-03-29 15:00:00', 18.400113147335233],
#   ['2004-03-29 16:00:00', 17.189223388184033],
#   ['2004-03-29 17:00:00', 16.17058039305047],
#   ['2004-03-29 18:00:00', 15.604806557102842],
#   ['2004-03-29 19:00:00', 14.538176077011055],
#   ['2004-03-29 20:00:00', 13.411438799002823],
#   ['2004-03-29 21:00:00', 11.728833283859645],
#   ['2004-03-29 22:00:00', 11.807546011048732],
#   ['2004-03-29 23:00:00', 11.4344696268783],
#   ['2004-03-30 00:00:00', 10.994911452343946],
#   ['2004-03-30 01:00:00', 11.701746744368638],
#   ['2004-03-30 02:00:00', 10.688948921764858],
#   ['2004-03-30 03:00:00', 10.38831134370906],
#   ['2004-03-30 04:00:00', 10.95690769923971],
#   ['2004-03-30 05:00:00', 10.643495290589353],
#   ['2004-03-30 06:00:00', 11.081197709901556],
#   ['2004-03-30 07:00:00', 10.98804217943589],
#   ['2004-03-30 08:00:00', 12.070013975240169],
#   ['2004-03-30 09:00:00', 13.579452536339492],
#   ['2004-03-30 10:00:00', 15.148745923757488],
#   ['2004-03-30 11:00:00', 16.230415911657317],
#   ['2004-03-30 12:00:00', 17.88528287397189],
#   ['2004-03-30 13:00:00', 18.833606054410843],
#   ['2004-03-30 14:00:00', 19.402769041109533],
#   ['2004-03-30 15:00:00', 19.75156077313611],
#   ['2004-03-30 16:00:00', 18.739630546265474],
#   ['2004-03-30 17:00:00', 18.138822644985716],
#   ['2004-03-30 18:00:00', 16.574558852895848],
#   ['2004-03-30 19:00:00', 14.981802718101546],
#   ['2004-03-30 20:00:00', 14.226997809410431],
#   ['2004-03-30 21:00:00', 13.585120364600536],
#   ['2004-03-30 22:00:00', 12.638628922300214],
#   ['2004-03-30 23:00:00', 11.90746212850975],
#   ['2004-03-31 00:00:00', 11.421185167780965],
#   ['2004-03-31 01:00:00', 11.450076660893867],
#   ['2004-03-31 02:00:00', 11.302807855072103],
#   ['2004-03-31 03:00:00', 10.80139457654638],
#   ['2004-03-31 04:00:00', 10.980766667575748],
#   ['2004-03-31 05:00:00', 10.778126375005778],
#   ['2004-03-31 06:00:00', 11.250814527556443],
#   ['2004-03-31 07:00:00', 11.327076836593905],
#   ['2004-03-31 08:00:00', 13.110970064825802],
#   ['2004-03-31 09:00:00', 14.12410330765399],
#   ['2004-03-31 10:00:00', 16.799282271521026],
#   ['2004-03-31 11:00:00', 18.161370807640413],
#   ['2004-03-31 12:00:00', 19.030668557984974],
#   ['2004-03-31 13:00:00', 20.18644831916798]]}

# %% [markdown]
# Combine forecast dates and output

# %%
forecast_df = pd.DataFrame(
    data=forecast_json_out['data'],
    columns=[time_col, target_col],
)

# %%
forecast_df.shape
# Out:
# (50, 2)

# %%
forecast_df.columns
# Out:
# Index(['datetime', 'T'], dtype='object')

# %%
forecast_df.head()
# Out:
#               datetime          T
# 0  2004-03-29 12:00:00  17.405948
# 1  2004-03-29 13:00:00  18.532345
# 2  2004-03-29 14:00:00  18.981799
# 3  2004-03-29 15:00:00  18.400113
# 4  2004-03-29 16:00:00  17.189223

# %%
forecast_df.tail()
# Out:
#                datetime          T
# 45  2004-03-31 09:00:00  14.124103
# 46  2004-03-31 10:00:00  16.799282
# 47  2004-03-31 11:00:00  18.161371
# 48  2004-03-31 12:00:00  19.030669
# 49  2004-03-31 13:00:00  20.186448

# %% [markdown]
# Plot train and forecast side-by-side

# %%
train_df['color'] = 'b'
train_df.set_index(time_col)[target_col].plot(figsize=figsize, color=train_df['color']);
# Out:
# C:\Users\saira\AppData\Local\Temp\ipykernel_23496\2998340865.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['color'] = 'b'

# %%
forecast_df['color'] = 'r'
forecast_df.set_index(time_col).plot(figsize=figsize, color=forecast_df['color']);

# %% [markdown]
# Combine train and forecast sets

# %%
df = pd.concat([train_df, forecast_df]).reset_index(drop=True)

# %%
df.shape
# Out:
# (500, 15)

# %%
df.head()
# Out:
#               datetime  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0  2004-03-10 18:00:00     2.6       1360.0     150.0      11.9
# 1  2004-03-10 19:00:00     2.0       1292.0     112.0       9.4
# 2  2004-03-10 20:00:00     2.2       1402.0      88.0       9.0
# 3  2004-03-10 21:00:00     2.2       1376.0      80.0       9.2
# 4  2004-03-10 22:00:00     1.6       1272.0      51.0       6.5
#
#    PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# 0         1046.0    166.0        1056.0    113.0        1692.0       1268.0
# 1          955.0    103.0        1174.0     92.0        1559.0        972.0
# 2          939.0    131.0        1140.0    114.0        1555.0       1074.0
# 3          948.0    172.0        1092.0    122.0        1584.0       1203.0
# 4          836.0    131.0        1205.0    116.0        1490.0       1110.0
#
#      RH      AH     T color
# 0  48.9  0.7578  13.6     b
# 1  47.7  0.7255  13.3     b
# 2  54.0  0.7502  11.9     b
# 3  60.0  0.7867  11.0     b
# 4  59.6  0.7888  11.2     b

# %%
df.tail()
# Out:
#                 datetime  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 495  2004-03-31 09:00:00     NaN          NaN       NaN       NaN
# 496  2004-03-31 10:00:00     NaN          NaN       NaN       NaN
# 497  2004-03-31 11:00:00     NaN          NaN       NaN       NaN
# 498  2004-03-31 12:00:00     NaN          NaN       NaN       NaN
# 499  2004-03-31 13:00:00     NaN          NaN       NaN       NaN
#
#      PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# 495            NaN      NaN           NaN      NaN           NaN          NaN
# 496            NaN      NaN           NaN      NaN           NaN          NaN
# 497            NaN      NaN           NaN      NaN           NaN          NaN
# 498            NaN      NaN           NaN      NaN           NaN          NaN
# 499            NaN      NaN           NaN      NaN           NaN          NaN
#
#      RH  AH          T color
# 495 NaN NaN  14.124103     r
# 496 NaN NaN  16.799282     r
# 497 NaN NaN  18.161371     r
# 498 NaN NaN  19.030669     r
# 499 NaN NaN  20.186448     r

# %% [markdown]
# Plot combined train and forecast sets with the vertical black line as the cut-off

# %%
df.set_index(time_col)[target_col].plot(figsize=figsize, color='r')
plt.axvline(x=len(train_df), color='black', label='Train/Forecast set cut-off')
plt.text(x=len(train_df)-9, y=forecast_df[target_col].max(), s='Train', fontweight='bold', fontsize=14)
plt.text(x=len(train_df)+1, y=forecast_df[target_col].max(), s='Forecast', fontweight='bold', fontsize=14)
plt.ylabel(ylabel='Temperature (' + u'\N{DEGREE SIGN}' + 'C)')
plt.title(label='Hourly Recorded Temperature', fontweight='bold', fontsize=20)
plt.show();

# %% [markdown]
# Plot original dataset to compare

# %%
figsize = (16, 8)
dataset.set_index(time_col)[target_col].plot(figsize=figsize);
plt.ylabel(ylabel='Temperature' + u'\N{DEGREE SIGN}' + 'C)')
plt.title(label='Hourly Recorded Temperature', fontweight='bold', fontsize=20)
plt.show();

# %% [markdown]
# Plot original dataset (blue) with SYBIL forecasted values (red)

# %%
df.set_index(time_col)[target_col].plot(figsize=figsize, color='r')
dataset.set_index(time_col)[target_col].plot(figsize=figsize);
plt.axvline(x=len(train_df), color='black', label='Train/Forecast set cut-off')
plt.text(x=len(train_df)-9, y=forecast_df[target_col].max(), s='Train', fontweight='bold', fontsize=14)
plt.text(x=len(train_df)+1, y=forecast_df[target_col].max(), s='Forecast', fontweight='bold', fontsize=14)
plt.ylabel(ylabel='Temperature' + u'\N{DEGREE SIGN}' + 'C)')
plt.title(label='Hourly Recorded Temperature', fontweight='bold', fontsize=20)
plt.show();
