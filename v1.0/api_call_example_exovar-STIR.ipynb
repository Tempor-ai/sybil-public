# %% [markdown]
# Check Python version

# %%
# !python --version
# Out:
# Python 3.9.18

# %% [markdown]
# Import libraries

# %%
import json
import yaml
import requests
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %% [markdown]
# ### **Extract Data**

# %%
file_name = 'Returns_short_interest_data_train.csv'

# %%
dataset = pd.read_csv(file_name)

# %%
dataset.shape
# Out:
# (788, 15)

# %%
dataset.columns
# Out:
# Index(['date', 'log_dp', 'log_dy', 'log_ep', 'log_de', 'bm', 'ntis', 'tbl',
#        'lty', 'ltr', 'tml', 'dfy', 'dfr', 'infl_lag', 'target'],
#       dtype='object')

# %%
dataset.head()
# Out:
#          date    log_dp    log_dy    log_ep    log_de        bm      ntis  \
# 0  1937-05-01 -2.999429 -2.999429 -2.648946 -0.350483  0.489382  0.028278
# 1  1937-06-01 -2.908721 -2.908721 -2.577364 -0.331357  0.504961  0.031266
# 2  1937-07-01 -3.034560 -3.034560 -2.660885 -0.373675  0.464649  0.027225
# 3  1937-08-01 -3.006598 -3.006598 -2.589993 -0.416605  0.481935  0.031064
# 4  1937-09-01 -2.883131 -2.883131 -2.422915 -0.460216  0.553147  0.035847
#
#       tbl     lty     ltr     tml     dfy     dfr  infl_lag    target
# 0  0.0041  0.0282  0.0053  0.0241  0.0151 -0.0013 -2.999429 -0.006041
# 1  0.0036  0.0285 -0.0018  0.0249  0.0165  0.0071 -2.908721 -0.054103
# 2  0.0028  0.0277  0.0138  0.0249  0.0166 -0.0099 -3.034560  0.098758
# 3  0.0029  0.0286 -0.0104  0.0257  0.0168  0.0087 -3.006598 -0.051425
# 4  0.0031  0.0284  0.0045  0.0253  0.0188 -0.0020 -2.883131 -0.139868

# %%
dataset.tail()
# Out:
#            date    log_dp    log_dy    log_ep    log_de        bm      ntis  \
# 783  2002-08-01 -4.054990 -4.054990 -3.454868 -0.600122  0.284412  0.025483
# 784  2002-09-01 -3.943471 -3.943471 -3.301014 -0.642457  0.324555  0.029393
# 785  2002-10-01 -4.020567 -4.020567 -3.411479 -0.609089  0.293437  0.025778
# 786  2002-11-01 -4.070296 -4.070296 -3.495323 -0.574973  0.276975  0.023009
# 787  2002-12-01 -4.002328 -4.002328 -3.462264 -0.540064  0.295386  0.025838
#
#         tbl     lty     ltr     tml     dfy     dfr  infl_lag    target
# 783  0.0162  0.0510  0.0464  0.0348  0.0121 -0.0012 -4.054990  0.005711
# 784  0.0163  0.0480  0.0417  0.0317  0.0125 -0.0087 -3.943471 -0.110377
# 785  0.0158  0.0508 -0.0294  0.0350  0.0141  0.0054 -4.020567  0.087282
# 786  0.0123  0.0521 -0.0122  0.0398  0.0131  0.0252 -4.070296  0.057994
# 787  0.0119  0.0484  0.0507  0.0365  0.0124 -0.0146 -4.002328 -0.059826

# %% [markdown]
# Define the required time and target columns

# %%
time_col = dataset.columns[0]
target_col = dataset.columns[-1]
dataset[time_col] = dataset[time_col].astype(str)

# %% [markdown]
# Change target column to float

# %%
# dataset[target_col] = dataset[target_col].astype(float)

# %%
# dataset.head()

# %% [markdown]
# Split dataset into train and test sets

# %%
train_size = 0.8
train_points = int(train_size*len(dataset))
train_df = dataset.iloc[:train_points]
test_df = dataset.iloc[train_points:]

# %% [markdown]
# Plot graph

# %%
figsize = (16, 8)
train_df.set_index(time_col)[target_col].plot(figsize=figsize);

# %% [markdown]
# ### **Train API**

# %% [markdown]
# Train data: convert df to list-of-list

# %%
train_data = []
for value in train_df.values:
    train_data.append(list(value))

# %%
train_data[:2]
# Out:
# [['1937-05-01',
#   -2.9994291354353173,
#   -2.9994291354353173,
#   -2.648946161744506,
#   -0.3504829736908111,
#   0.4893824051284986,
#   0.0282780631029591,
#   0.0040999999999999,
#   0.0282,
#   0.0053,
#   0.0241,
#   0.0150999999999999,
#   -0.0013,
#   -2.9994291354353173,
#   -0.0060406666666666],
#  ['1937-06-01',
#   -2.908720896564361,
#   -2.908720896564361,
#   -2.5773637606099187,
#   -0.3313571359544425,
#   0.5049610205527995,
#   0.0312661665365891,
#   0.0036,
#   0.0285,
#   -0.0018,
#   0.0249,
#   0.0165,
#   0.0071,
#   -2.908720896564361,
#   -0.054103]]

# %% [markdown]
# Custom Model Request (optional)

# %%
# Default model request
# model_request = {
#     'type': 'meta_lr',
#     'scorers': ['smape', 'mase'],
#     'params': {
#         'preprocessors': [
#             {'type': 'dartsimputer'},
#             {'type': 'minmaxscaler'},
#         ],
#         'base_models': [
#             {'type': 'darts_naive'},
#             {'type': 'darts_seasonalnaive'},
#             {'type': 'darts_autotheta'},
#             {'type': 'darts_autoarima'},
#             {'type': 'darts_autoets'},
#         ],
#     },
# }

# Onboard NeuralProphet customized model request
# np_external_model_request = {
#     'params': {
#       'changepoints_range': 0.2,
#       'epochs': 2,
#       'growth': 'off'
#     },
#     'metrics': [],
#     'type': 'neuralprophet',
# }
# np_external_model_request = None

# Customized model request
# model_request = {
#     'type': 'meta_wa',  # 'meta_naive', 'meta_wa'
#     'scorers': ['mase', 'smape'],
#     'params': {
#         'preprocessors': [
#             {'type': 'dartsimputer'},
#             {'type': 'simpleimputer', 'params': {'strategy': 'mean'}},
#             {'type': 'minmaxscaler'},
#         ],
#         'base_models': [
#             {'type': 'darts_naive'},
#             {'type': 'darts_seasonalnaive'},
#             {'type': 'darts_autotheta'},
#             {'type': 'stats_autotheta'},
#             {'type': 'darts_autoets'},
#             {'type': 'stats_autoets'},
#             {'type': 'darts_autoarima'},
#             {'type': 'stats_autoarima'},
#             # {'type': 'darts_tbats'},
#             # {'type': 'darts_linearregression'},
#             {'type': 'darts_lightgbm',
#              'params': {
#                  'lags': 12,
#                  'output_chunk_length': 6,
#                  'verbose': -1
#             }}
#             # {'type': 'neuralprophet',
#             #  'external_params': np_external_model_request
#             # }  # Onboard NeuralProphet external service
#         ],
#     },
# }

# %% [markdown]
# This is for JSON model_request

# %%
# file_path = 'model_request.json'
# # For writing the model request to a json file
# with open(file_path, 'r') as file:
#     model_request = json.load(file)

# %% [markdown]
# This is for YAML model_request

# %%
file_path = 'model_request.yaml'
# For reading the model request from a yaml file
with open(file_path, 'r') as file:
    model_request = yaml.safe_load(file)

# %% [markdown]
# Train API JSON Payload

# %%
api_json = {
    'data': train_data,
    'model': model_request  # (optional) can be commented out
}

# %% [markdown]
# Build URL

# %%
with open('url.yaml', 'r') as file:
    url_dict = yaml.safe_load(file)

# %%
# URL to our SYBIL AWS service
protocol = url_dict['protocol']
host = url_dict['host']
port = url_dict['port']
endpoint = 'train'

url = '%s://%s:%s/%s' % (protocol, host, str(port), endpoint)

# %%
# protocol, host, port

# %% [markdown]
# Call endpoint, receive response JSON, write to output file

# %%
# %%time
response = requests.post(url, json=api_json)
print(response)
print()

# %%
train_json_out = response.json()  # dict output
train_json_out
# Out:
# {'model': '...',
#  'type': 'meta_wa',
#  'metrics': [{'type': 'mase', 'value': 0.7571979132365093},
#   {'type': 'smape', 'value': 157.16846386290217}]}

# %% [markdown]
# ### **Forecast API**

# %% [markdown]
# Forecast Dates: predict the next 32 years of temperature anomaly data (1980-2012)

# %%
test_data = []
for value in test_df.drop(columns=target_col).values:
    test_data.append(list(value))

# %%
test_data[:2]
# Out:
# [['1989-11-01',
#   -3.455508698863343,
#   -3.455508698863343,
#   -2.7047031108088846,
#   -0.7508055880544587,
#   0.3972257017961992,
#   -0.0270221107060077,
#   0.0769,
#   0.0808,
#   0.0078,
#   0.0038999999999999,
#   0.0092,
#   -0.0007999999999999,
#   -3.455508698863343],
#  ['1989-12-01',
#   -3.465170131921834,
#   -3.465170131921834,
#   -2.7377745518509062,
#   -0.727395580070928,
#   0.3904547435711172,
#   -0.0123231066872625,
#   0.0762999999999999,
#   0.0816,
#   -0.0006,
#   0.0053,
#   0.0096,
#   0.0012,
#   -3.465170131921834]]

# %% [markdown]
# Model from Train API

# %%
model = train_json_out['model']

# %% [markdown]
# Forecast API JSON Payload

# %%
api_json = {
    'model': model,
    'data': test_data
}

# %% [markdown]
# Build URL (same as train except for the endpoint)

# %%
endpoint = 'forecast'

url = '%s://%s:%s/%s' % (protocol, host, str(port), endpoint)

# %% [markdown]
# Call endpoint, receive response JSON, write to output file

# %%
# %%time
response = requests.post(url, json=api_json)
print(response)
print()
# Out:
# <Response [200]>
#
# CPU times: user 74.7 ms, sys: 0 ns, total: 74.7 ms
# Wall time: 1.91 s

# %%
forecast_json_out = response.json()  # dict output
forecast_json_out
# Out:
# {'data': [['1989-11-01', -0.0021992324178470002],
#   ['1989-12-01', -0.0178963104978171],
#   ['1990-01-01', -0.015137872618602017],
#   ['1990-02-01', 0.008054207502350842],
#   ['1990-03-01', 0.00013159372935995497],
#   ['1990-04-01', 0.00900976412435184],
#   ['1990-05-01', -0.0018387710990995306],
#   ['1990-06-01', 0.0053724351408043014],
#   ['1990-07-01', 0.0033848966757554365],
#   ['1990-08-01', -0.00025854374058064615],
#   ['1990-09-01', -0.0002738992878902845],
#   ['1990-10-01', -0.0002346296437783919],
#   ['1990-11-01', 0.008840819756760132],
#   ['1990-12-01', 0.00775438448453835],
#   ['1991-01-01', -0.002608082301818718],
#   ['1991-02-01', 0.007613903203880669],
#   ['1991-03-01', 0.011634775558071186],
#   ['1991-04-01', 0.001330318210329877],
#   ['1991-05-01', 0.008181552178599307],
#   ['1991-06-01', 0.004481249670277588],
#   ['1991-07-01', 0.011432659561028295],
#   ['1991-08-01', -0.0011389453508245707],
#   ['1991-09-01', 0.014422995632463562],
#   ['1991-10-01', -0.0019275307400054673],
#   ['1991-11-01', 0.0004990843122318489],
#   ['1991-12-01', 6.694215245479007e-05],
#   ['1992-01-01', -0.007902890556624133],
#   ['1992-02-01', -0.026440824268106736],
#   ['1992-03-01', -0.017794471623371107],
#   ['1992-04-01', 0.0034973130046038127],
#   ['1992-05-01', -0.0007248009241935167],
#   ['1992-06-01', 0.003416309576323979],
#   ['1992-07-01', -0.00387568854582155],
#   ['1992-08-01', -0.0009344709068952023],
#   ['1992-09-01', -0.0013320977405110864],
#   ['1992-10-01', -0.0026337316447699616],
#   ['1992-11-01', 0.001224411448242427],
#   ['1992-12-01', -0.003547208085066461],
#   ['1993-01-01', 0.002756732246244504],
#   ['1993-02-01', 0.0010221305105784849],
#   ['1999-03-01', 0.0007853918356268837],
#   ['1999-04-01', 0.001969442638321368],
#   ['1999-05-01', 0.003745757006541093],
#   ['1999-06-01', -0.0005933435772395887],
#   ['1999-07-01', 0.004860535485116604],
#   ['1999-08-01', 0.0024343470876000174],
#   ['1999-09-01', -0.00711180933071858],
#   ['1999-10-01', 0.004201373065837796],
#   ['1999-11-01', 0.010362507412325767],
#   ['1999-12-01', 0.0017179707437599671],
#   ['2000-01-01', 0.006935399391197894],
#   ['2000-02-01', 0.005434868901985354],
#   ['2000-03-01', 0.007164673663024484],
#   ['2000-04-01', -0.005169654874192455],
#   ['2000-05-01', 0.011654878092169512],
#   ['2000-06-01', 0.0076385470058122655],
#   ['2000-07-01', 0.003708798386385507],
#   ['2000-08-01', -0.004560367222431483],
#   ['2000-09-01', -0.0062198709527227156],
#   ['2000-10-01', -0.020356371425267483],
#   ['2000-11-01', -0.00029000549944723235],
#   ['2000-12-01', 0.012207982793421208],
#   ['2001-01-01', 0.007929162263960609],
#   ['2001-02-01', 0.006390601579837381],
#   ['2001-03-01', -0.0020602622929256206],
#   ['2001-04-01', 0.004633317815991975],
#   ['2001-05-01', 0.011282501997438188],
#   ['2001-06-01', 0.005217084475135725],
#   ['2001-07-01', 0.005023693066652107],
#   ['2001-08-01', -0.002258574773668128],
#   ['2001-09-01', 0.002083730119740214],
#   ['2001-10-01', 0.007784422834772124],
#   ['2001-11-01', 0.0007213930469231675],
#   ['2001-12-01', 0.006638792303506811],
#   ['2002-01-01', 0.009459014300003465],
#   ['2002-02-01', 0.0013980842179052602],
#   ['2002-03-01', 0.0047077449542560264],
#   ['2002-04-01', 0.008156100299031941],
#   ['2002-05-01', 0.015227873551169965],
#   ['2002-06-01', -0.0013664150764346448],
#   ['2002-07-01', 0.012238610768167655],
#   ['2002-08-01', 0.0028380619855423598],
#   ['2002-09-01', -0.001418631904596295],
#   ['2002-10-01', -0.00577756994649668],
#   ['2002-11-01', -0.004525796313900938],
#   ['2002-12-01', -0.018726082271259905]]}

# %% [markdown]
# Combine forecast dates and output

# %%
forecast_df = pd.DataFrame(
    data=forecast_json_out['data'],
    columns=[time_col, target_col],
)

# %%
forecast_df.shape
# Out:
# (158, 2)

# %%
forecast_df.columns
# Out:
# Index(['date', 'target'], dtype='object')

# %%
forecast_df.head()
# Out:
#          date    target
# 0  1989-11-01 -0.002199
# 1  1989-12-01 -0.017896
# 2  1990-01-01 -0.015138
# 3  1990-02-01  0.008054
# 4  1990-03-01  0.000132

# %%
forecast_df.tail()
# Out:
#            date    target
# 153  2002-08-01  0.002838
# 154  2002-09-01 -0.001419
# 155  2002-10-01 -0.005778
# 156  2002-11-01 -0.004526
# 157  2002-12-01 -0.018726

# %% [markdown]
# Plot train and forecast side-by-side

# %%
train_df['color'] = 'b'
train_df.set_index(time_col)[target_col].plot(figsize=figsize, color=train_df['color']);
# Out:
# /tmp/ipykernel_88491/2998340865.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['color'] = 'b'

# %%
forecast_df['color'] = 'r'
forecast_df.set_index(time_col).plot(figsize=figsize, color=forecast_df['color']);

# %% [markdown]
# Combine train and test sets

# %%
df = pd.concat([train_df, forecast_df]).reset_index(drop=True)

# %%
df.shape
# Out:
# (788, 16)

# %%
df.head()
# Out:
#          date    log_dp    log_dy    log_ep    log_de        bm      ntis  \
# 0  1937-05-01 -2.999429 -2.999429 -2.648946 -0.350483  0.489382  0.028278
# 1  1937-06-01 -2.908721 -2.908721 -2.577364 -0.331357  0.504961  0.031266
# 2  1937-07-01 -3.034560 -3.034560 -2.660885 -0.373675  0.464649  0.027225
# 3  1937-08-01 -3.006598 -3.006598 -2.589993 -0.416605  0.481935  0.031064
# 4  1937-09-01 -2.883131 -2.883131 -2.422915 -0.460216  0.553147  0.035847
#
#       tbl     lty     ltr     tml     dfy     dfr  infl_lag    target color
# 0  0.0041  0.0282  0.0053  0.0241  0.0151 -0.0013 -2.999429 -0.006041     b
# 1  0.0036  0.0285 -0.0018  0.0249  0.0165  0.0071 -2.908721 -0.054103     b
# 2  0.0028  0.0277  0.0138  0.0249  0.0166 -0.0099 -3.034560  0.098758     b
# 3  0.0029  0.0286 -0.0104  0.0257  0.0168  0.0087 -3.006598 -0.051425     b
# 4  0.0031  0.0284  0.0045  0.0253  0.0188 -0.0020 -2.883131 -0.139868     b

# %%
df.tail()
# Out:
#            date  log_dp  log_dy  log_ep  log_de  bm  ntis  tbl  lty  ltr  tml  \
# 783  2002-08-01     NaN     NaN     NaN     NaN NaN   NaN  NaN  NaN  NaN  NaN
# 784  2002-09-01     NaN     NaN     NaN     NaN NaN   NaN  NaN  NaN  NaN  NaN
# 785  2002-10-01     NaN     NaN     NaN     NaN NaN   NaN  NaN  NaN  NaN  NaN
# 786  2002-11-01     NaN     NaN     NaN     NaN NaN   NaN  NaN  NaN  NaN  NaN
# 787  2002-12-01     NaN     NaN     NaN     NaN NaN   NaN  NaN  NaN  NaN  NaN
#
#      dfy  dfr  infl_lag    target color
# 783  NaN  NaN       NaN  0.002838     r
# 784  NaN  NaN       NaN -0.001419     r
# 785  NaN  NaN       NaN -0.005778     r
# 786  NaN  NaN       NaN -0.004526     r
# 787  NaN  NaN       NaN -0.018726     r

# %% [markdown]
# Plot combined train and test sets with the vertical black line as the cut-off

# %%
df.set_index(time_col)[target_col].plot(figsize=figsize, color='r')
plt.axvline(x=len(train_df), color='black', label='Train/Test set cut-off')
plt.text(x=len(train_df)-9, y=forecast_df[target_col].max(), s='Train', fontweight='bold', fontsize=14)
plt.text(x=len(train_df)+1, y=forecast_df[target_col].max(), s='Test', fontweight='bold', fontsize=14)
plt.ylabel(ylabel='Temperature Anomaly (' + u'\N{DEGREE SIGN}' + 'C)')
plt.title(label='Annual Temperature Anomaly (Train: 1850-1979) (Test: 1980-2012)', fontweight='bold', fontsize=20)
plt.show();

# %% [markdown]
# Plot original dataset to compare

# %%
figsize = (16, 8)
dataset.set_index(time_col)[target_col].plot(figsize=figsize);
plt.ylabel(ylabel='Temperature Anomaly (' + u'\N{DEGREE SIGN}' + 'C)')
plt.title(label='Annual Temperature Anomaly (1850-2012)', fontweight='bold', fontsize=20)
plt.show();

# %% [markdown]
# Plot original dataset (blue) with SYBIL forecasted values (red)

# %%
df.set_index(time_col)[target_col].plot(figsize=figsize, color='r')
dataset.set_index(time_col)[target_col].plot(figsize=figsize);
plt.axvline(x=len(train_df), color='black', label='Train/Test set cut-off')
plt.text(x=len(train_df)-9, y=forecast_df[target_col].max(), s='Train', fontweight='bold', fontsize=14)
plt.text(x=len(train_df)+1, y=forecast_df[target_col].max(), s='Test', fontweight='bold', fontsize=14)
plt.ylabel(ylabel='Temperature Anomaly (' + u'\N{DEGREE SIGN}' + 'C)')
plt.title(label='Annual Temperature Anomaly (Train: 1850-1979) (Test: 1980-2012)', fontweight='bold', fontsize=20)
plt.show();
