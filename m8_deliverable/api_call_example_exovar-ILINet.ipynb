# %% [markdown]
# Check Python version

# %%
# !python --version
# Out:
# Python 3.9.18

# %% [markdown]
# Import libraries

# %%
import json
import yaml
import requests
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
from darts import TimeSeries
from darts.datasets import ILINetDataset
from darts.utils.missing_values import missing_values_ratio, fill_missing_values

# %% [markdown]
# ### **Extract Data**

# %%
# Through online Darts
series = ILINetDataset().load()
dataset = series.pd_dataframe().reset_index()
dataset.index.name = None

# %%
dataset.shape
# Out:
# (1305, 12)

# %%
dataset.columns
# Out:
# Index(['DATE', '% WEIGHTED ILI', '%UNWEIGHTED ILI', 'AGE 0-4', 'AGE 25-49',
#        'AGE 25-64', 'AGE 5-24', 'AGE 50-64', 'AGE 65', 'ILITOTAL',
#        'NUM. OF PROVIDERS', 'TOTAL PATIENTS'],
#       dtype='object', name='component')

# %%
dataset.head()
# Out:
# component       DATE  % WEIGHTED ILI  %UNWEIGHTED ILI  AGE 0-4  AGE 25-49  \
# 0         1997-10-12         1.10148          1.21686    179.0        NaN
# 1         1997-10-19         1.20007          1.28064    199.0        NaN
# 2         1997-10-26         1.37876          1.23906    228.0        NaN
# 3         1997-11-02         1.19920          1.14473    188.0        NaN
# 4         1997-11-09         1.65618          1.26112    217.0        NaN
#
# component  AGE 25-64  AGE 5-24  AGE 50-64  AGE 65  ILITOTAL  \
# 0              157.0     205.0        NaN    29.0     570.0
# 1              151.0     242.0        NaN    23.0     615.0
# 2              153.0     266.0        NaN    34.0     681.0
# 3              193.0     236.0        NaN    36.0     653.0
# 4              162.0     280.0        NaN    41.0     700.0
#
# component  NUM. OF PROVIDERS  TOTAL PATIENTS
# 0                      192.0         46842.0
# 1                      191.0         48023.0
# 2                      219.0         54961.0
# 3                      213.0         57044.0
# 4                      213.0         55506.0

# %%
dataset['DATE'] = pd.to_datetime(dataset['DATE'])

# %%
dataset.tail()
# Out:
# component       DATE  % WEIGHTED ILI  %UNWEIGHTED ILI  AGE 0-4  AGE 25-49  \
# 1300      2022-09-11         2.02422          1.94821  12548.0     6978.0
# 1301      2022-09-18         2.03228          1.97359  13386.0     6709.0
# 1302      2022-09-25         2.28328          2.20031  15904.0     6877.0
# 1303      2022-10-02         2.36912          2.30242  16977.0     6869.0
# 1304      2022-10-09         2.56561          2.56080  17521.0    10009.0
#
# component  AGE 25-64  AGE 5-24  AGE 50-64  AGE 65  ILITOTAL  \
# 1300             NaN   13475.0     2701.0  2632.0   38334.0
# 1301             NaN   14467.0     2599.0  2435.0   39596.0
# 1302             NaN   16571.0     2633.0  2473.0   44458.0
# 1303             NaN   16622.0     2764.0  2633.0   45865.0
# 1304             NaN   18196.0     3716.0  3458.0   52900.0
#
# component  NUM. OF PROVIDERS  TOTAL PATIENTS
# 1300                  3324.0       1967653.0
# 1301                  3316.0       2006289.0
# 1302                  3329.0       2020531.0
# 1303                  3335.0       1992031.0
# 1304                  3356.0       2065759.0

# %%
col_list = ['% WEIGHTED ILI', '%UNWEIGHTED ILI', 'AGE 0-4', 'AGE 25-49',
       'AGE 25-64', 'AGE 5-24', 'AGE 50-64', 'AGE 65', 'ILITOTAL',
       'NUM. OF PROVIDERS', 'TOTAL PATIENTS']

# %%
series = TimeSeries.from_dataframe(dataset, 'DATE', col_list)
series_filled = fill_missing_values(series)
df_filled = series_filled.pd_dataframe().reset_index()

# %% [markdown]
# Define the required time and target columns

# %%
time_col = dataset.columns[0]
target_col = dataset.columns[-1]
dataset[time_col] = dataset[time_col].astype(str)

# %% [markdown]
# Change target column to float

# %%
figsize = (16, 8)
dataset.set_index(time_col)[target_col].plot(figsize=figsize);

# %%
dataset[dataset.DATE < '2021'].set_index(time_col).plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
dataset[dataset.DATE < '2017-08'].set_index(time_col).plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
# trim the anomaly part
dataset_partial = df_filled[df_filled.DATE < '2017-08']

# %%
dataset_partial
# Out:
# component       DATE  % WEIGHTED ILI  %UNWEIGHTED ILI  AGE 0-4  AGE 25-49  \
# 0         1997-10-12        1.101480         1.216860    179.0        0.0
# 1         1997-10-19        1.200070         1.280640    199.0        0.0
# 2         1997-10-26        1.378760         1.239060    228.0        0.0
# 3         1997-11-02        1.199200         1.144730    188.0        0.0
# 4         1997-11-09        1.656180         1.261120    217.0        0.0
# ...              ...             ...              ...      ...        ...
# 1029      2017-07-02        0.859531         0.961603   1771.0     1121.0
# 1030      2017-07-09        0.818998         0.955818   1728.0     1111.0
# 1031      2017-07-16        0.752505         0.827597   1545.0     1004.0
# 1032      2017-07-23        0.731146         0.811886   1549.0      908.0
# 1033      2017-07-30        0.733295         0.818527   1576.0      953.0
#
# component  AGE 25-64  AGE 5-24  AGE 50-64  AGE 65  ILITOTAL  \
# 0              157.0     205.0        0.0    29.0     570.0
# 1              151.0     242.0        0.0    23.0     615.0
# 2              153.0     266.0        0.0    34.0     681.0
# 3              193.0     236.0        0.0    36.0     653.0
# 4              162.0     280.0        0.0    41.0     700.0
# ...              ...       ...        ...     ...       ...
# 1029          6090.0    1748.0      489.0   467.0    5596.0
# 1030          6090.0    1564.0      505.0   418.0    5326.0
# 1031          6090.0    1578.0      462.0   372.0    4961.0
# 1032          6090.0    1421.0      450.0   419.0    4747.0
# 1033          6090.0    1515.0      459.0   376.0    4879.0
#
# component  NUM. OF PROVIDERS  TOTAL PATIENTS
# 0                      192.0         46842.0
# 1                      191.0         48023.0
# 2                      219.0         54961.0
# 3                      213.0         57044.0
# 4                      213.0         55506.0
# ...                      ...             ...
# 1029                  1422.0        581945.0
# 1030                  1456.0        557219.0
# 1031                  1405.0        599446.0
# 1032                  1384.0        584688.0
# 1033                  1377.0        596071.0
#
# [1034 rows x 12 columns]

# %%
dataset_partial['DATE'] = dataset_partial['DATE'].astype('str')
# Out:
# /tmp/ipykernel_88117/1473158665.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset_partial['DATE'] = dataset_partial['DATE'].astype('str')

# %%
# dataset[target_col] = dataset[target_col].astype(float)

# %%
# dataset.head()

# %% [markdown]
# Split dataset into train and test sets

# %%
train_size = 0.8
train_points = int(train_size*len(dataset_partial))
train_df = dataset_partial.iloc[:train_points]
test_df = dataset_partial.iloc[train_points:]

# %% [markdown]
# Plot graph

# %%
train_df['DATE'] = train_df['DATE'].astype('str')
# Out:
# /tmp/ipykernel_88117/1870464413.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['DATE'] = train_df['DATE'].astype('str')

# %% [markdown]
# ### **Train API**

# %% [markdown]
# Train data: convert df to list-of-list

# %%
train_data = []
for value in train_df.values:
    train_data.append(list(value))

# %%
train_data[:2]
# Out:
# [['1997-10-12',
#   1.10148,
#   1.21686,
#   179.0,
#   0.0,
#   157.0,
#   205.0,
#   0.0,
#   29.0,
#   570.0,
#   192.0,
#   46842.0],
#  ['1997-10-19',
#   1.20007,
#   1.28064,
#   199.0,
#   0.0,
#   151.0,
#   242.0,
#   0.0,
#   23.0,
#   615.0,
#   191.0,
#   48023.0]]

# %% [markdown]
# Custom Model Request (optional)

# %%
# Default model request
# model_request = {
#     'type': 'meta_lr',
#     'scorers': ['smape', 'mase'],
#     'params': {
#         'preprocessors': [
#             {'type': 'dartsimputer'},
#             {'type': 'minmaxscaler'},
#         ],
#         'base_models': [
#             {'type': 'darts_naive'},
#             {'type': 'darts_seasonalnaive'},
#             {'type': 'darts_autotheta'},
#             {'type': 'darts_autoarima'},
#             {'type': 'darts_autoets'},
#         ],
#     },
# }

# Onboard NeuralProphet customized model request
np_external_model_request = {
    'type': 'neuralprophet',
    'metrics': ['rmse', 'mae'],
    # 'metrics': ['smape', 'mase'],
    'params': {
        'lagged_regressors': [
            {'index': 0},
            {'index': 1},
            {'index': 2},
            # {'index': 3},
            # {'index': 4},
            # {'index': 5},
            # {'index': 6},
            # {'index': 7},
            # {'index': 8}
        ],
        "epochs": 5
    },
}
# np_external_model_request = None

# Customized model request
model_request = {
    'type': 'meta_wa',  # 'meta_naive', 'meta_wa'
    'scorers': ['mase', 'smape'],
    'params': {
        'preprocessors': [
            {'type': 'dartsimputer', 'params': {'fill': 'auto'}},
            {'type': 'simpleimputer', 'params': {'strategy': 'mean'}},
            {'type': 'minmaxscaler'},
        ],
        'base_models': [
            {'type': 'darts_naive'},
            {'type': 'darts_seasonalnaive'},
            {'type': 'darts_autotheta'},
            {'type': 'stats_autotheta'},
            {'type': 'darts_autoets'},
            {'type': 'stats_autoets'},
            # {'type': 'darts_autoarima'},
            # {'type': 'stats_autoarima'},
            # {'type': 'darts_tbats'},
            # {'type': 'darts_linearregression'},
            {'type': 'darts_lightgbm',
             'params': {
                'lags': 12,
                'lags_future_covariates': [0, 1, 2],
                'output_chunk_length': 6,
                'verbose': -1
            }},  #'lags_past_covariates' 
            # {'type': 'darts_rnn',
            #  'params': {
            #     'model': 'LSTM',
            #     'hidden_dim': 10,
            #     'n_rnn_layers': 3
            # }},
            # {'type': 'neuralprophet', 
            #  'external_params': np_external_model_request
            # }  # Onboard NeuralProphet external service
        ],
    },
}

# %% [markdown]
# This is for JSON model_request

# %%
# file_path = 'model_request.json'
# # For writing the model request to a json file
# with open(file_path, 'r') as file:
#     model_request = json.load(file)

# %% [markdown]
# This is for YAML model_request

# %%
# file_path = 'model_request.yaml'
# # For reading the model request from a yaml file
# with open(file_path, 'r') as file:
#     model_request = yaml.safe_load(file)

# %% [markdown]
# Train API JSON Payload

# %%
api_json = {
    'data': train_data,
    'model': model_request  # (optional) can be commented out
}

# %% [markdown]
# Build URL

# %%
with open('url.yaml', 'r') as file:
    url_dict = yaml.safe_load(file)

# %%
# URL to our SYBIL AWS service
protocol = url_dict['protocol']
host = url_dict['host']
port = url_dict['port']
endpoint = 'train'

url = '%s://%s:%s/%s' % (protocol, host, str(port), endpoint)

# %%
# protocol, host, port

# %% [markdown]
# Call endpoint, receive response JSON, write to output file

# %%
# %%time
response = requests.post(url, json=api_json)
print(response)
print()
# Out:
# <Response [200]>
#
# CPU times: user 52.6 ms, sys: 9.02 ms, total: 61.7 ms
# Wall time: 3min 20s

# %%
train_json_out = response.json()  # dict output
train_json_out
# Out:
# {'model': '...',
#  'type': 'meta_wa',
#  'metrics': [{'type': 'mase', 'value': 3.2770510183642836},
#   {'type': 'smape', 'value': 10.551258018834286}]}

# %% [markdown]
# ### **Forecast API**

# %% [markdown]
# Forecast Dates: predict the next 32 years of temperature anomaly data (1980-2012)

# %%
test_data = []
for value in test_df.drop(columns=target_col).values:
    test_data.append(list(value))

# %%
test_data[:2]
# Out:
# [['2013-08-18',
#   0.755639,
#   0.779136,
#   1367.0,
#   870.0,
#   6090.0,
#   1338.0,
#   302.0,
#   198.0,
#   4075.0,
#   1299.0],
#  ['2013-08-25',
#   0.761847,
#   0.797653,
#   1364.0,
#   919.0,
#   6090.0,
#   1366.0,
#   331.0,
#   188.0,
#   4168.0,
#   1276.0]]

# %% [markdown]
# Model from Train API

# %%
model = train_json_out['model']

# %% [markdown]
# Forecast API JSON Payload

# %%
api_json = {
    'model': model,
    'data': test_data
}

# %% [markdown]
# Build URL (same as train except for the endpoint)

# %%
endpoint = 'forecast'

url = '%s://%s:%s/%s' % (protocol, host, str(port), endpoint)

# %% [markdown]
# Call endpoint, receive response JSON, write to output file

# %%
# %%time
response = requests.post(url, json=api_json)
print(response)
print()
# Out:
# <Response [200]>
#
# CPU times: user 32.2 ms, sys: 330 µs, total: 32.5 ms
# Wall time: 1.5 s

# %%
forecast_json_out = response.json()  # dict output
forecast_json_out
# Out:
# {'data': [['2013-08-18', 497978.95176072745],
#   ['2013-08-25', 498748.24490093265],
#   ['2013-09-01', 495030.2024764712],
#   ['2013-09-08', 495072.3946233584],
#   ['2013-09-15', 503184.6793001272],
#   ['2013-09-22', 501460.7959735794],
#   ['2013-09-29', 508749.2087727055],
#   ['2013-10-06', 515947.132327612],
#   ['2013-10-13', 576670.9044606752],
#   ['2013-10-20', 584304.518424146],
#   ['2013-10-27', 587070.0264156599],
#   ['2013-11-03', 589080.0312657127],
#   ['2013-11-10', 594807.4723449992],
#   ['2013-11-17', 593178.0446818834],
#   ['2013-11-24', 589151.9015875185],
#   ['2013-12-01', 580745.7525368656],
#   ['2013-12-08', 577300.9713527616],
#   ['2013-12-15', 583885.9917331301],
#   ['2013-12-22', 583071.7258818895],
#   ['2013-12-29', 579617.8887019277],
#   ['2014-01-05', 572388.6783148681],
#   ['2014-01-12', 572484.6785693859],
#   ['2014-01-19', 584216.5098202754],
#   ['2014-01-26', 589774.645708564],
#   ['2014-02-02', 592825.1121340004],
#   ['2014-02-09', 601289.4230478258],
#   ['2014-02-16', 607353.4624545322],
#   ['2014-02-23', 596363.2120997445],
#   ['2014-03-02', 588503.3038582015],
#   ['2014-03-09', 585414.3719853763],
#   ['2014-03-16', 582185.5927802537],
#   ['2014-03-23', 576135.6048869435],
#   ['2014-03-30', 584380.7722268394],
#   ['2014-04-06', 585294.4874134469],
#   ['2014-04-13', 587438.906305149],
#   ['2014-04-20', 579105.8686916741],
#   ['2014-04-27', 572573.8779570713],
#   ['2014-05-04', 568259.8239170506],
#   ['2014-05-11', 567895.8338280539],
#   ['2014-05-18', 564696.330727473],
#   ['2014-05-25', 557664.1283380417],
#   ['2014-06-01', 552061.3042567649],
#   ['2014-06-08', 533464.3699813612],
#   ['2014-06-15', 523463.8148396941],
#   ['2014-06-22', 519900.3636150352],
#   ['2014-06-29', 517684.3899064789],
#   ['2014-07-06', 517324.0943843129],
#   ['2014-07-13', 513701.6926613045],
#   ['2014-07-20', 513563.3381384163],
#   ['2014-07-27', 510691.9461505009],
#   ['2017-05-21', 587277.0832744024],
#   ['2017-05-28', 572611.256573619],
#   ['2017-06-04', 556400.0649649032],
#   ['2017-06-11', 545581.4431931529],
#   ['2017-06-18', 539545.6014056882],
#   ['2017-06-25', 540554.3486101024],
#   ['2017-07-02', 538283.0880983665],
#   ['2017-07-09', 537146.104524392],
#   ['2017-07-16', 535645.5312114708],
#   ['2017-07-23', 534877.7453906899],
#   ['2017-07-30', 531203.7549247597]]}

# %% [markdown]
# Combine forecast dates and output

# %%
forecast_df = pd.DataFrame(
    data=forecast_json_out['data'],
    columns=[time_col, target_col],
)

# %%
forecast_df.shape
# Out:
# (207, 2)

# %%
forecast_df.columns
# Out:
# Index(['DATE', 'TOTAL PATIENTS'], dtype='object')

# %%
forecast_df.head()
# Out:
#          DATE  TOTAL PATIENTS
# 0  2013-08-18   497978.951761
# 1  2013-08-25   498748.244901
# 2  2013-09-01   495030.202476
# 3  2013-09-08   495072.394623
# 4  2013-09-15   503184.679300

# %%
forecast_df.tail()
# Out:
#            DATE  TOTAL PATIENTS
# 202  2017-07-02   538283.088098
# 203  2017-07-09   537146.104524
# 204  2017-07-16   535645.531211
# 205  2017-07-23   534877.745391
# 206  2017-07-30   531203.754925

# %% [markdown]
# Plot train and forecast side-by-side

# %%
train_df['color'] = 'b'
train_df.set_index(time_col)[target_col].plot(figsize=figsize, color=train_df['color']);
# Out:
# /tmp/ipykernel_88117/2998340865.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['color'] = 'b'

# %%
forecast_df['color'] = 'r'
forecast_df.set_index(time_col).plot(figsize=figsize, color=forecast_df['color']);

# %% [markdown]
# Combine train and forecast sets

# %%
df = pd.concat([train_df, forecast_df]).reset_index(drop=True)

# %%
df.shape
# Out:
# (1034, 13)

# %%
df.head()
# Out:
#          DATE  % WEIGHTED ILI  %UNWEIGHTED ILI  AGE 0-4  AGE 25-49  AGE 25-64  \
# 0  1997-10-12         1.10148          1.21686    179.0        0.0      157.0
# 1  1997-10-19         1.20007          1.28064    199.0        0.0      151.0
# 2  1997-10-26         1.37876          1.23906    228.0        0.0      153.0
# 3  1997-11-02         1.19920          1.14473    188.0        0.0      193.0
# 4  1997-11-09         1.65618          1.26112    217.0        0.0      162.0
#
#    AGE 5-24  AGE 50-64  AGE 65  ILITOTAL  NUM. OF PROVIDERS  TOTAL PATIENTS  \
# 0     205.0        0.0    29.0     570.0              192.0         46842.0
# 1     242.0        0.0    23.0     615.0              191.0         48023.0
# 2     266.0        0.0    34.0     681.0              219.0         54961.0
# 3     236.0        0.0    36.0     653.0              213.0         57044.0
# 4     280.0        0.0    41.0     700.0              213.0         55506.0
#
#   color
# 0     b
# 1     b
# 2     b
# 3     b
# 4     b

# %%
df.tail()
# Out:
#             DATE  % WEIGHTED ILI  %UNWEIGHTED ILI  AGE 0-4  AGE 25-49  \
# 1029  2017-07-02             NaN              NaN      NaN        NaN
# 1030  2017-07-09             NaN              NaN      NaN        NaN
# 1031  2017-07-16             NaN              NaN      NaN        NaN
# 1032  2017-07-23             NaN              NaN      NaN        NaN
# 1033  2017-07-30             NaN              NaN      NaN        NaN
#
#       AGE 25-64  AGE 5-24  AGE 50-64  AGE 65  ILITOTAL  NUM. OF PROVIDERS  \
# 1029        NaN       NaN        NaN     NaN       NaN                NaN
# 1030        NaN       NaN        NaN     NaN       NaN                NaN
# 1031        NaN       NaN        NaN     NaN       NaN                NaN
# 1032        NaN       NaN        NaN     NaN       NaN                NaN
# 1033        NaN       NaN        NaN     NaN       NaN                NaN
#
#       TOTAL PATIENTS color
# 1029   538283.088098     r
# 1030   537146.104524     r
# 1031   535645.531211     r
# 1032   534877.745391     r
# 1033   531203.754925     r

# %% [markdown]
# Plot combined train and forecast sets with the vertical black line as the cut-off

# %%
df.set_index(time_col)[target_col].plot(figsize=figsize, color='r')
plt.axvline(x=len(train_df), color='black', label='Train/Forecast set cut-off')
plt.text(x=len(train_df)-9, y=forecast_df[target_col].max(), s='Train', fontweight='bold', fontsize=14)
plt.text(x=len(train_df)+1, y=forecast_df[target_col].max(), s='Forecast', fontweight='bold', fontsize=14)
plt.ylabel(ylabel='# Patients')
plt.title(label='Total Number of Patients (Train: 1997-2013) (Forecast: 2013-2017)', fontweight='bold', fontsize=20)
plt.show();

# %% [markdown]
# Plot original dataset to compare

# %%
figsize = (16, 8)
dataset.set_index(time_col)[target_col].plot(figsize=figsize);
plt.ylabel(ylabel='# Patients')
plt.title(label='Total Number of Patients (1997-2022)', fontweight='bold', fontsize=20)
plt.show();

# %% [markdown]
# Plot original dataset (blue) with SYBIL forecasted values (red)

# %%
df.set_index(time_col)[target_col].plot(figsize=figsize, color='r')
dataset.set_index(time_col)[target_col].plot(figsize=figsize);
plt.axvline(x=len(train_df), color='black', label='Train/Forecast set cut-off')
plt.text(x=len(train_df)-9, y=forecast_df[target_col].max(), s='Train', fontweight='bold', fontsize=14)
plt.text(x=len(train_df)+1, y=forecast_df[target_col].max(), s='Forecast', fontweight='bold', fontsize=14)
plt.ylabel(ylabel='# Patients')
plt.title(label='Total Number of Patients (Train: 1997-2013) (Forecast: 2013-2017)', fontweight='bold', fontsize=20)
plt.show();
